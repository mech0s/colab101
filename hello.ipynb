# %% [markdown]
# <a href="https://colab.research.google.com/github/mech0s/colab101/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
print ("Hello World! Revision 3")
# Out:
# Hello World! Revision 3

# %%
sourceURI = "https://dodcio.defense.gov/Portals/0/Documents/Library/DevSecOpsActivitesToolsGuidebookTables.xlsx"
xls = pd.ExcelFile(sourceURI)

# %%
df1 = pd.read_excel(xls,"Plan")

# %%
df1["Phase"]="Plan"
df1["ID"] = df1.index + 1

# %%
df1
# Out:
#                                 Activities   Baseline  \
# 0               Change management planning   REQUIRED
# 1             Configuration identification   REQUIRED
# 2   Configuration management (CM) planning   REQUIRED
# 3                          Database design  PREFERRED
# 4                            Design review  PREFERRED
# 5                 DevSecOps process design   REQUIRED
# 6            Documentation version control   REQUIRED
# 7                           IaC deployment   REQUIRED
# 8     Mission-Based Cyber Risk Assessments   REQUIRED
# 9                 Project/Release planning   REQUIRED
# 10        Project team onboarding planning   REQUIRED
# 11                         Risk management   REQUIRED
# 12           Software requirement analysis   REQUIRED
# 13                           System design   REQUIRED
# 14                              Test Audit   REQUIRED
# 15                         Test Deployment   REQUIRED
# ...

# %%
pd.concat([df1,df1])
# Out:
#                                 Activities   Baseline  \
# 0               Change management planning   REQUIRED
# 1             Configuration identification   REQUIRED
# 2   Configuration management (CM) planning   REQUIRED
# 3                          Database design  PREFERRED
# 4                            Design review  PREFERRED
# 5                 DevSecOps process design   REQUIRED
# 6            Documentation version control   REQUIRED
# 7                           IaC deployment   REQUIRED
# 8     Mission-Based Cyber Risk Assessments   REQUIRED
# 9                 Project/Release planning   REQUIRED
# 10        Project team onboarding planning   REQUIRED
# 11                         Risk management   REQUIRED
# 12           Software requirement analysis   REQUIRED
# 13                           System design   REQUIRED
# 14                              Test Audit   REQUIRED
# 15                         Test Deployment   REQUIRED
# ...

# %%
df2 = pd.read_excel(xls,"Plan")

# %%
df3 = pd.read_excel(xls,"Deploy")

# %%
df3.replace(np.nan, '')
# Out:
#                                      Activities     Baseline  \
# 0                           Artifact deployment    PREFERRED
# 1                             Artifact download    PREFERRED
# 2                              Compliance Tests     REQUIRED
# 3        Create linked clone of VM master image    PREFERRED
# 4                  Database artifact deployment    PREFERRED
# 5                 Database Schema installation     PREFERRED
# 6                    Formal Qualification Tests  AS REQUIRED
# 7               Human Systems Integration Tests  AS REQUIRED
# 8        Infrastructure provisioning automation    PREFERRED
# 9                        Interoperability Tests     REQUIRED
# 10              Interoperability Certifications  AS REQUIRED
# 11         Mission Based Cyber Risk Assessments     REQUIRED
# 12         Mission-Oriented Developmental Tests     REQUIRED
# 13                      Operational Assessments  AS REQUIRED
# ...

# %%
pd.concat([df2,df3],keys=["Plan","Deploy"], names=["Phase","IDinPhase"])
# Out:
#                                                    Activities     Baseline  \
# Phase  IDinPhase
# Plan   0                           Change management planning     REQUIRED
#        1                         Configuration identification     REQUIRED
#        2               Configuration management (CM) planning     REQUIRED
#        3                                      Database design    PREFERRED
#        4                                        Design review    PREFERRED
#        5                             DevSecOps process design     REQUIRED
#        6                        Documentation version control     REQUIRED
#        7                                       IaC deployment     REQUIRED
#        8                 Mission-Based Cyber Risk Assessments     REQUIRED
#        9                             Project/Release planning     REQUIRED
#        10                    Project team onboarding planning     REQUIRED
# ...

# %%
xls.sheet_names
# Out:
# ['Cover',
#  'Overview',
#  'Continuous Activities',
#  'Plan',
#  'Develop',
#  'Build',
#  'Test',
#  'Release',
#  'Deliver',
#  'Deploy',
#  'Operate',
#  'Monitor',
#  'Feedback',
#  'Tools']

# %%
phaseNames = [ 'Plan',
 'Develop',
 'Build',
 'Test',
 'Release',
 'Deliver',
 'Deploy',
 'Operate',
 'Monitor',
 'Feedback']

# %%
phaseActivityData = pd.read_excel(xls,phaseNames[0])

# %%
phaseDataList = []

# %%
for phName in phaseNames:
  phaseDataList.append(pd.read_excel(xls,phName))

# %%
phaseActivityData = pd.concat(phaseDataList,keys=phaseNames, names=["Phase","IDinPhase"])

# %%
phaseActivityData
# Out:
#                                                 Activities   Baseline  \
# Phase    IDinPhase
# Plan     0                      Change management planning   REQUIRED
#          1                    Configuration identification   REQUIRED
#          2          Configuration management (CM) planning   REQUIRED
#          3                                 Database design  PREFERRED
#          4                                   Design review  PREFERRED
# ...                                                    ...        ...
# Monitor  12                                     Test Audit   REQUIRED
#          13                       Test configuration audit  PREFERRED
#          14                     User Evaluation / Feedback   REQUIRED
# Feedback 0                          Revise Product Backlog   REQUIRED
#          1                      User Evaluation / Feedback   REQUIRED
#
#                                                                  SSDF  \
# Phase    IDinPhase
# ...
